# %%
#I.Escribir un programa que me permita aplicar el 10% de descuento si la compra es mayor a $100
Compra_total= float((input("Ingrese monto de la compra")))
descuento=0
if (Compra_total >100):
    descuento= Compra_total * 0.1
Pago_con_descuento= Compra_total -descuento
print(f"Monto total=${Pago_con_descuento}")

# %%
#II.Sabiendo que la fórmula para obtener el área de un triángulo es a = (b x h) / 2, donde b es la longitud de la base del triángulo, y h es su altura. Escribir un programa que permita realizar el cálculo del área de un triángulo. Si el área contiene valores decimales, imprimir el resultado con dos dígitos.
Base=float((input("Ingrese la base del triángulo")))
Altura=float((input("Ingrese la altura del triángulo")))
Area_Triangulo= f" {Base * Altura / 2: .2f}"
print (f"Area del Triángulo ={Area_Triangulo}")

# %%
#III.La fórmula para el Índice de Masa Corportal es IMC = kg/m2 donde kg es el peso de la persona en kilogramos y m2 es la altura en metros al cuadrado. Realizar un programa que calcula el IMC cuando se le provee el peso y la altura
kg = float((input("Ingrese su peso en kg")))    
altura = float((input("Ingrese su altura en metros")))
IMC= kg / altura ** 2
print(f"Su IMC es:{IMC} kg/m2")
